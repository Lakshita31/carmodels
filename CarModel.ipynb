# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Dtaa=pd.read_csv('CarModels.csv')

# %%
Dtaa
# Out:
#            Car       Model  Volume  Weight    CO2  Volume1
# 0       Toyoty        Aygo    1000     790   99.0      1.0
# 1   Mitsubishi  Space Star    1200    1160   95.0      1.2
# 2        Skoda      Citigo    1000     929   95.0      1.0
# 3         Fiat         500     900     865   90.0      0.9
# 4         Mini      Cooper    1500    1140  105.0      1.5
# 5           VW         Up!    1000     929  105.0      1.0
# 6        Skoda       Fabia       0    1109   90.0      0.0
# 7     Mercedes     A-Class    1500    1365   92.0      1.5
# 8         Ford      Fiesta    1500    1112   98.0      1.5
# 9         Audi          A1    1600    1150    0.0      1.6
# 10     Hyundai         I20    1100     980   99.0      1.1
# 11      Suzuki       Swift    1300     990  101.0      1.3
# 12        Ford      Fiesta    1000    1112   99.0      1.0
# 13       Honda       Civic    1600    1252   94.0      1.6
# 14      Hundai         I30       0    1326   97.0      0.0
# 15        Opel       Astra    1600    1330   97.0      1.6
# 16         BMW           1    1600    1365   99.0      1.6
# 17       Mazda           3    2200    1280  104.0      2.2
# 18       Skoda       Rapid    1600    1119  104.0      1.6
# 19        Ford       Focus    2000    1328  105.0      2.0
# 20        Ford      Mondeo    1600    1584   94.0      1.6
# 21        Opel    Insignia    2000    1428   99.0      2.0
# 22    Mercedes     C-Class    2100    1365   99.0      2.1
# 23       Skoda     Octavia    1600    1415   99.0      1.6
# 24       Volvo         S60    2000    1415   99.0      2.0
# 25    Mercedes         CLA    1500    1465    NaN      1.5
# 26        Audi          A4    2000    1490  104.0      2.0
# 27        Audi          A6    2000    1725  114.0      2.0
# 28       Volvo         V70    1600    1523  109.0      1.6
# 29         BMW           5    2000    1705  114.0      2.0
# 30    Mercedes     E-Class    2100    1605  115.0      2.1
# 31       Volvo        XC70    2000    1746  117.0      2.0
# 32        Ford       B-Max    1600    1235  104.0      1.6
# 33         BMW         216    1600    1390  108.0      1.6
# 34        Opel      Zafira    1600    1405  109.0      1.6
# 35    Mercedes         SLK    2500    1395  120.0      2.5

# %%
Dtaa.size
# Out:
# 216

# %%
Dtaa.shape
# Out:
# (36, 6)

# %%
Dtaa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Car      36 non-null     object
#  1   Model    36 non-null     object
#  2   Volume   36 non-null     int64
#  3   Weight   36 non-null     int64
#  4   CO2      35 non-null     float64
#  5   Volume1  36 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.8+ KB

# %%
Dtaa.sample()
# Out:
#       Car Model  Volume  Weight    CO2  Volume1
# 31  Volvo  XC70    2000    1746  117.0      2.0

# %%
Dtaa.describe()
# Out:
#             Volume       Weight         CO2    Volume1
# count    36.000000    36.000000   35.000000  36.000000
# mean   1527.777778  1292.277778   99.200000   1.527778
# std     539.635385   242.123889   18.838009   0.539635
# min       0.000000   790.000000    0.000000   0.000000
# 25%    1275.000000  1117.250000   97.000000   1.275000
# 50%    1600.000000  1329.000000   99.000000   1.600000
# 75%    2000.000000  1418.250000  105.000000   2.000000
# max    2500.000000  1746.000000  120.000000   2.500000

# %%
Dtaa.head()
# Out:
#           Car       Model  Volume  Weight    CO2  Volume1
# 0      Toyoty        Aygo    1000     790   99.0      1.0
# 1  Mitsubishi  Space Star    1200    1160   95.0      1.2
# 2       Skoda      Citigo    1000     929   95.0      1.0
# 3        Fiat         500     900     865   90.0      0.9
# 4        Mini      Cooper    1500    1140  105.0      1.5

# %%
Dtaa.tail()
# Out:
#          Car   Model  Volume  Weight    CO2  Volume1
# 31     Volvo    XC70    2000    1746  117.0      2.0
# 32      Ford   B-Max    1600    1235  104.0      1.6
# 33       BMW     216    1600    1390  108.0      1.6
# 34      Opel  Zafira    1600    1405  109.0      1.6
# 35  Mercedes     SLK    2500    1395  120.0      2.5

# %%
Dtaa.dropna(inplace=True)

# %%
plt.hist(x='Weight')
plt.show()

# %%
plt.hist(Dtaa,100)
plt.show()

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\computer\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.0.post7)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\computer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sklearn import linear_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from sklearn import linear_model
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
Dtaa
# Out:
#            Car       Model  Volume  Weight    CO2
# 0       Toyoty        Aygo    1000     790   99.0
# 1   Mitsubishi  Space Star    1200    1160   95.0
# 2        Skoda      Citigo    1000     929   95.0
# 3         Fiat         500     900     865   90.0
# 4         Mini      Cooper    1500    1140  105.0
# 5           VW         Up!    1000     929  105.0
# 6        Skoda       Fabia       0    1109   90.0
# 7     Mercedes     A-Class    1500    1365   92.0
# 8         Ford      Fiesta    1500    1112   98.0
# 9         Audi          A1    1600    1150    0.0
# 10     Hyundai         I20    1100     980   99.0
# 11      Suzuki       Swift    1300     990  101.0
# 12        Ford      Fiesta    1000    1112   99.0
# 13       Honda       Civic    1600    1252   94.0
# 14      Hundai         I30       0    1326   97.0
# 15        Opel       Astra    1600    1330   97.0
# 16         BMW           1    1600    1365   99.0
# 17       Mazda           3    2200    1280  104.0
# 18       Skoda       Rapid    1600    1119  104.0
# 19        Ford       Focus    2000    1328  105.0
# 20        Ford      Mondeo    1600    1584   94.0
# 21        Opel    Insignia    2000    1428   99.0
# 22    Mercedes     C-Class    2100    1365   99.0
# 23       Skoda     Octavia    1600    1415   99.0
# 24       Volvo         S60    2000    1415   99.0
# 26        Audi          A4    2000    1490  104.0
# 27        Audi          A6    2000    1725  114.0
# 28       Volvo         V70    1600    1523  109.0
# 29         BMW           5    2000    1705  114.0
# 30    Mercedes     E-Class    2100    1605  115.0
# 31       Volvo        XC70    2000    1746  117.0
# 32        Ford       B-Max    1600    1235  104.0
# 33         BMW         216    1600    1390  108.0
# 34        Opel      Zafira    1600    1405  109.0
# 35    Mercedes         SLK    2500    1395  120.0

# %%
df=Dtaa

# %%
x=df[['Volume','Weight']]
y=df['CO2']

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
predicted_CO2=regr.predict([[2200,1300]])
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predicted_CO2
# Out:
# array([100.82501757])

# %%
regr.coef_
# Out:
# array([0.00201872, 0.02129936])

# %%
x=df[['Volume','CO2']]
y=df['Weight']

# %%
regr=linear_model.LinearRegression()
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
predicted_Weight=regr.predict([[2100,110]])
# Out:
# C:\Users\Admin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predicted_Weight
# Out:
# array([1453.90281162])

# %%
regr.coef_
# Out:
# array([0.24549115, 2.43326806])
